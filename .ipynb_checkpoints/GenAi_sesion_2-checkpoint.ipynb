# %%
# !pip install -U langchain-google-genai
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    -------------- ------------------------- 0.5/1.4 MB 540.5 kB/s eta 0:00:02
#    -------------- ------------------------- 0.5/1.4 MB 540.5 kB/s eta 0:00:02
#    ---------------------- ----------------- 0.8/1.4 MB 558.9 kB/s eta 0:00:02
#    ---------------------- ----------------- 0.8/1.4 MB 558.9 kB/s eta 0:00:02
#    ---------------------- ----------------- 0.8/1.4 MB 558.9 kB/s eta 0:00:02
#    ----------------------------- ---------- 1.0/1.4 MB 565.4 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.0/1.4 MB 565.4 kB/s eta 0:00:01
#    ------------------------------------- -- 1.3/1.4 MB 541.1 kB/s eta 0:00:01
# ...

# %%
# import os
# os.environ["GOOGLE_API_KEY"] = "AIzaSyBxNt9BwWpD3uZnDNwwMmBV1ReXRa-83Io"

# %%
import langchain_google_genai

# %%
dir(langchain_google_genai)
# Out:
# ['AqaInput',
#  'AqaOutput',
#  'ChatGoogleGenerativeAI',
#  'DoesNotExistsException',
#  'GenAIAqa',
#  'GoogleGenerativeAI',
#  'GoogleGenerativeAIEmbeddings',
#  'GoogleVectorStore',
#  'HarmBlockThreshold',
#  'HarmCategory',
#  'Modality',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_common',
#  '_compat',
#  '_enums',
#  '_function_utils',
#  '_genai_extension',
#  '_image_utils',
#  'chat_models',
#  'embeddings',
#  'genai_aqa',
#  'google_vector_store',
#  'llms']

# %% [markdown]
# - Model name
# - api key
# - temprature
#     - thinking level
#     - less imiagination to moore imagination
#     - you are coming from ? India
#     - I am coming from India
#     - I am coming from India, India is a Greatest,1947
# - top p
#     - Commulative probability
#     -  top p=0.95
# - top k=3 how many words required to genrate ans
#     - tell me about virat kholi
#     - virat kholi is a ---- batsman
#     - indian batsman,best,right handed
# - do_sample
#     - do_sample=True all words are mix pick

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash",api_key="AIzaSyBxNt9BwWpD3uZnDNwwMmBV1ReXRa-83Io")

# %%
response= llm.invoke("Sing a ballad of LangChain.")
response.content
# Out:
# '(Verse 1)\nIn realms of silicon, where thoughts take their flight,\nA giant awoke, with a mind burning bright.\nThe LLM did ponder, a marvel untold,\nBut structure and purpose, it struggled to hold.\nIt spoke mighty truths, and could answer with grace,\nYet a sequence of actions, it found hard to chase.\nTo connect to the world, beyond its own mind,\nA framework was needed, a hero to find.\n\n(Chorus)\nOh, LangChain, LangChain, a whisper, a plea,\nTo bind the great models, for you and for me.\nA symphony woven, a path clearly shown,\nFor the wisdom of AI, to truly be known.\n\n(Verse 2)\nThen from the deep code, a new hero did rise,\nWith elegant patterns, and wisdom in its eyes.\nLangChain its name, a framework so grand,\nTo guide the great models, throughout all the land.\nIt spoke of "Chains" and of "Agents" so keen,\nOf "Tools" it could wield, a magnificent scene.\nTo break down the complex, to make tasks so clear,\nDispelling the silence, banishing all fear.\n\n(Chorus)\nOh, La
# ...
